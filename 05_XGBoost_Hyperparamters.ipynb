# %% [markdown]
# # Model 5
# Hyperparameter tuning for XGBoost
#
# ## Restult
# <code>
# Best Model XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.05, max_delta_step=0, max_depth=3,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=1500, n_jobs=0, num_parallel_tree=1,
#              objective='reg:squarederror', random_state=1, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)
# </code >
#
# ## Future:
# Data Manipulation along with hyperparamters tuning

# %%
# reading data from google drive 
# data paths whether notebook is run locally or google colab
import os
try:
    from google.colab import drive
    drive.mount('/content/drive')
    COMPETETION_PATH = "/content/drive/MyDrive/30-days-of-ml-competition1"
    TRAIN_DATA_PATH = "/content/drive/MyDrive/30-days-of-ml-competition1/data/train.csv"
    TEST_DATA_PATH = "/content/drive/MyDrive/30-days-of-ml-competition1/data/test.csv"
    OUTPUT_PATH = "/content/drive/MyDrive/30-days-of-ml-competition1/output"
except:
    TRAIN_DATA_PATH = os.path.join("data", "train.csv")
    TEST_DATA_PATH = os.path.join("data", "test.csv")

print(f"Training Path {TRAIN_DATA_PATH}")
print(f"Testing Path {TEST_DATA_PATH}")
# Out:
# Training Path data/train.csv
# Testing Path data/test.csv

# %%
# library imports
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# preprocessing
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder, OrdinalEncoder
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

# modeling
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor

# evaluation
from sklearn.metrics import mean_absolute_error

# %%
def read_organise_data(train=TRAIN_DATA_PATH):
    """read the data from a path and splitting to features and target

    Args:
        train (path, optional): The path of training data file to. Defaults to TRAIN_DATA_PATH.

    Returns:
        X, y: X for features and y for target
    """
    full_df = pd.read_csv(train, index_col="id")
    print(f"Shape of Dataset: {full_df.shape}")
    return full_df

df= read_organise_data()
X_test = pd.read_csv(TEST_DATA_PATH, index_col='id')
print(f"Shape of Test set {X_test.shape}")
# Out:
# Shape of Dataset: (300000, 25)
# Shape of Test set (200000, 24)

# %% [markdown]
# ## Understanding Data

# %%
df.describe()
# Out:
#                cont0          cont1  ...         cont13         target
# count  300000.000000  300000.000000  ...  300000.000000  300000.000000
# mean        0.527335       0.460926  ...       0.508273       8.241979
# std         0.230599       0.214003  ...       0.222950       0.746555
# min        -0.118039      -0.069309  ...       0.151050       0.140329
# 25%         0.405965       0.310494  ...       0.300669       7.742071
# 50%         0.497053       0.427903  ...       0.472400       8.191373
# 75%         0.668060       0.615113  ...       0.758447       8.728634
# max         1.058443       0.887253  ...       0.905992      10.411992
#
# [8 rows x 15 columns]

# %%
# checking for null values in the full dataset
df.isnull().any().sum() # no null value in dataset
# Out:
# 0

# %%
y = df.target.copy()
X = df.drop('target', axis=1).copy()

# %%
# splitting the data
X_train, X_valid, y_train, y_valid = train_test_split(X,y, test_size=0.2,
                                                      random_state= 1)

# %%
# categorical columns start with cat
categorical_cols = [cname for cname in X.columns if 'cat' in cname]
# numerical columns starts with cont
numerical_cols = [cname for cname in X.columns if 'cont' in cname]

# %%
# checking the cardinality of the categorical columns
for cname in categorical_cols:
    num_unique = X[cname].nunique()
    print(f"{cname} has {num_unique}")
    if num_unique > 10:
        print(f"\t{cname} has a high cardinality")

# eventhough cat9 col has more than 10 unique values, we will still use the OnehotEncoder
# Out:
# cat0 has 2
# cat1 has 2
# cat2 has 2
# cat3 has 4
# cat4 has 4
# cat5 has 4
# cat6 has 8
# cat7 has 8
# cat8 has 7
# cat9 has 15
# 	cat9 has a high cardinality

# %%
# numerical and categorical transformations
num_transformer = StandardScaler()
cat_transformer = OrdinalEncoder()
preprocessor = ColumnTransformer(transformers=[
    ('num', num_transformer, numerical_cols),
    ('cat', cat_transformer, categorical_cols),
])

# %%
def get_score(model, X_t=X_train, X_v=X_valid, y_t=y_train, y_v=y_valid):
    my_pipeline = Pipeline(steps=[
                                  ('preprocessor', preprocessor),
                                  ('model', model)
    ])
    my_pipeline.fit(X_t, y_t)
    preds = my_pipeline.predict(X_v)
    return mean_absolute_error(y_v, preds)

# %%
xgb_model = XGBRegressor(objective='reg:squarederror', random_state=1)
get_score(xgb_model)
# Out:
# 0.5740460076081315

# %%
X
# Out:
#         cat0  cat1  cat2  cat3  cat4  cat5  cat6  cat7  cat8  cat9  ...  \
# id                                                                  ...
# 1        1.0   1.0   1.0   2.0   1.0   1.0   0.0   4.0   2.0  13.0  ...
# 2        1.0   1.0   0.0   0.0   1.0   3.0   0.0   5.0   0.0  14.0  ...
# 3        0.0   0.0   0.0   2.0   1.0   3.0   0.0   3.0   0.0   5.0  ...
# 4        1.0   1.0   0.0   2.0   1.0   3.0   0.0   4.0   2.0  10.0  ...
# 6        0.0   0.0   0.0   2.0   1.0   3.0   0.0   4.0   0.0  13.0  ...
# ...      ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...
# 499993   1.0   1.0   0.0   0.0   1.0   3.0   0.0   4.0   0.0   8.0  ...
# 499996   0.0   1.0   0.0   2.0   1.0   1.0   0.0   4.0   4.0   5.0  ...
# 499997   1.0   1.0   0.0   2.0   1.0   2.0   0.0   4.0   6.0   5.0  ...
# 499998   0.0   1.0   0.0   2.0   1.0   1.0   0.0   4.0   4.0   8.0  ...
# 499999   0.0   0.0   0.0   2.0   0.0   3.0   0.0   4.0   0.0  14.0  ...
#
#            cont4     cont5     cont6     cont7     cont8     cont9    cont10  \
# id
# 1       0.610706  0.400361  0.160266  0.310921  0.389470  0.267559  0.237281
# 2       0.276853  0.533087  0.558922  0.516294  0.594928  0.341439  0.906013
# 3       0.285074  0.650609  0.375348  0.902567  0.555205  0.843531  0.748809
# 4       0.284667  0.668980  0.239061  0.732948  0.679618  0.574844  0.346010
# 6       0.287595  0.686964  0.420667  0.648182  0.684501  0.956692  1.000773
# ...          ...       ...       ...       ...       ...       ...       ...
# 499993  0.307883  0.769792  0.450538  0.934360  1.005077  0.853726  0.422541
# 499996  0.736713  0.528056  0.508502  0.358247  0.257825  0.433525  0.301015
# 499997  0.277074  0.688747  0.372425  0.364936  0.383224  0.551825  0.661007
# 499998  0.805963  0.344404  0.424243  0.382028  0.468819  0.351036  0.288768
# 499999  0.276785  0.565347  0.328669  0.789165  0.960406  0.776019  0.734707
#
#           cont11    cont12    cont13
# id
# 1       0.377873  0.322401  0.869850
# 2       0.921701  0.261975  0.465083
# 3       0.620126  0.541474  0.763846
# 4       0.714610  0.540150  0.280682
# 6       0.776742  0.625849  0.250823
# ...          ...       ...       ...
# 499993  1.063463  0.697685  0.506404
# 499996  0.268447  0.577055  0.823611
# 499997  0.629606  0.714139  0.245732
# 499998  0.611169  0.380254  0.332030
# 499999  0.484392  0.639754  0.689317
#
# [300000 rows x 24 columns]

# %%
# encoder
ordinal_encode = OrdinalEncoder()
X[categorical_cols] = ordinal_encode.fit_transform(X[categorical_cols])
X
# Out:
#         cat0  cat1  cat2  cat3  cat4  cat5  cat6  cat7  cat8  cat9  ...  \
# id                                                                  ...
# 1        1.0   1.0   1.0   2.0   1.0   1.0   0.0   4.0   2.0  13.0  ...
# 2        1.0   1.0   0.0   0.0   1.0   3.0   0.0   5.0   0.0  14.0  ...
# 3        0.0   0.0   0.0   2.0   1.0   3.0   0.0   3.0   0.0   5.0  ...
# 4        1.0   1.0   0.0   2.0   1.0   3.0   0.0   4.0   2.0  10.0  ...
# 6        0.0   0.0   0.0   2.0   1.0   3.0   0.0   4.0   0.0  13.0  ...
# ...      ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...
# 499993   1.0   1.0   0.0   0.0   1.0   3.0   0.0   4.0   0.0   8.0  ...
# 499996   0.0   1.0   0.0   2.0   1.0   1.0   0.0   4.0   4.0   5.0  ...
# 499997   1.0   1.0   0.0   2.0   1.0   2.0   0.0   4.0   6.0   5.0  ...
# 499998   0.0   1.0   0.0   2.0   1.0   1.0   0.0   4.0   4.0   8.0  ...
# 499999   0.0   0.0   0.0   2.0   0.0   3.0   0.0   4.0   0.0  14.0  ...
#
#            cont4     cont5     cont6     cont7     cont8     cont9    cont10  \
# id
# 1       0.610706  0.400361  0.160266  0.310921  0.389470  0.267559  0.237281
# 2       0.276853  0.533087  0.558922  0.516294  0.594928  0.341439  0.906013
# 3       0.285074  0.650609  0.375348  0.902567  0.555205  0.843531  0.748809
# 4       0.284667  0.668980  0.239061  0.732948  0.679618  0.574844  0.346010
# 6       0.287595  0.686964  0.420667  0.648182  0.684501  0.956692  1.000773
# ...          ...       ...       ...       ...       ...       ...       ...
# 499993  0.307883  0.769792  0.450538  0.934360  1.005077  0.853726  0.422541
# 499996  0.736713  0.528056  0.508502  0.358247  0.257825  0.433525  0.301015
# 499997  0.277074  0.688747  0.372425  0.364936  0.383224  0.551825  0.661007
# 499998  0.805963  0.344404  0.424243  0.382028  0.468819  0.351036  0.288768
# 499999  0.276785  0.565347  0.328669  0.789165  0.960406  0.776019  0.734707
#
#           cont11    cont12    cont13
# id
# 1       0.377873  0.322401  0.869850
# 2       0.921701  0.261975  0.465083
# 3       0.620126  0.541474  0.763846
# 4       0.714610  0.540150  0.280682
# 6       0.776742  0.625849  0.250823
# ...          ...       ...       ...
# 499993  1.063463  0.697685  0.506404
# 499996  0.268447  0.577055  0.823611
# 499997  0.629606  0.714139  0.245732
# 499998  0.611169  0.380254  0.332030
# 499999  0.484392  0.639754  0.689317
#
# [300000 rows x 24 columns]

# %%
# parameters to search 
params = { 'max_depth': [3,6,10],
           'learning_rate': [0.01, 0.05],
           'n_estimators': [500, 1000, 1250, 1500]}

# %%
def param_tuning(params):

        model = XGBRegressor(n_estimators=1000, max_depth=3, 
                        learning_rate=0.01, objective='reg:squarederror', random_state=1)
        grid_search = GridSearchCV(estimator=model, 
                        param_grid=params,
                        scoring='neg_mean_absolute_error', 
                        verbose=3)
        grid_search.fit(X, y)
        print("Best parameters:", grid_search.best_params_)
        print("Lowest MAE: ", (-grid_search.best_score_))
        return grid_search

# %%
grid_search_results = param_tuning(params)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV] learning_rate=0.01, max_depth=3, n_estimators=500 ...............
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  learning_rate=0.01, max_depth=3, n_estimators=500, score=-0.580, total= 1.5min
# [CV] learning_rate=0.01, max_depth=3, n_estimators=500 ...............
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  1.5min remaining:    0.0s
# [CV]  learning_rate=0.01, max_depth=3, n_estimators=500, score=-0.585, total= 1.5min
# [CV] learning_rate=0.01, max_depth=3, n_estimators=500 ...............
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:  3.0min remaining:    0.0s
# [CV]  learning_rate=0.01, max_depth=3, n_estimators=500, score=-0.582, total= 1.6min
# [CV] learning_rate=0.01, max_depth=3, n_estimators=500 ...............
# [CV]  learning_rate=0.01, max_depth=3, n_estimators=500, score=-0.583, total= 1.4min
# [CV] learning_rate=0.01, max_depth=3, n_estimators=500 ...............
# [CV]  learning_rate=0.01, max_depth=3, n_estimators=500, score=-0.583, total= 1.4min
# [CV] learning_rate=0.01, max_depth=3, n_estimators=1000 ..............
# [CV]  learning_rate=0.01, max_depth=3, n_estimators=1000, score=-0.577, total= 2.9min
# [CV] learning_rate=0.01, max_depth=3, n_estimators=1000 ..............
# [CV]  learning_rate=0.01, max_depth=3, n_estimators=1000, score=-0.583, total= 2.9min
# [CV] learning_rate=0.01, max_depth=3, n_estimators=1000 ..............
# [CV]  learning_rate=0.01, max_depth=3, n_estimators=1000, score=-0.579, total= 2.9min
# [CV] learning_rate=0.01, max_depth=3, n_estimators=1000 ..............
# [CV]  learning_rate=0.01, max_depth=3, n_estimators=1000, score=-0.581, total= 2.9min
# [CV] learning_rate=0.01, max_depth=3, n_estimators=1000 ..............
# [CV]  learning_rate=0.01, max_depth=3, n_estimators=1000, score=-0.581, total= 2.9min
# [CV] learning_rate=0.01, max_depth=3, n_estimators=1250 ..............
# [CV]  learning_rate=0.01, max_depth=3, n_estimators=1250, score=-0.577, total= 3.5min
# [CV] learning_rate=0.01, max_depth=3, n_estimators=1250 ..............
# [CV]  learning_rate=0.01, max_depth=3, n_estimators=1250, score=-0.582, total= 3.2min
# [CV] learning_rate=0.01, max_depth=3, n_estimators=1250 ..............
# [CV]  learning_rate=0.01, max_depth=3, n_estimators=1250, score=-0.578, total= 3.2min
# [CV] learning_rate=0.01, max_depth=3, n_estimators=1250 ..............
# [CV]  learning_rate=0.01, max_depth=3, n_estimators=1250, score=-0.580, total= 3.2min
# [CV] learning_rate=0.01, max_depth=3, n_estimators=1250 ..............
# [CV]  learning_rate=0.01, max_depth=3, n_estimators=1250, score=-0.580, total= 3.2min
# [CV] learning_rate=0.01, max_depth=3, n_estimators=1500 ..............
# [CV]  learning_rate=0.01, max_depth=3, n_estimators=1500, score=-0.576, total= 3.9min
# [CV] learning_rate=0.01, max_depth=3, n_estimators=1500 ..............
# [CV]  learning_rate=0.01, max_depth=3, n_estimators=1500, score=-0.581, total= 3.8min
# [CV] learning_rate=0.01, max_depth=3, n_estimators=1500 ..............
# [CV]  learning_rate=0.01, max_depth=3, n_estimators=1500, score=-0.578, total= 3.9min
# [CV] learning_rate=0.01, max_depth=3, n_estimators=1500 ..............
# [CV]  learning_rate=0.01, max_depth=3, n_estimators=1500, score=-0.579, total= 3.8min
# [CV] learning_rate=0.01, max_depth=3, n_estimators=1500 ..............
# [CV]  learning_rate=0.01, max_depth=3, n_estimators=1500, score=-0.579, total= 3.9min
# [CV] learning_rate=0.01, max_depth=6, n_estimators=500 ...............
# [CV]  learning_rate=0.01, max_depth=6, n_estimators=500, score=-0.575, total= 2.5min
# [CV] learning_rate=0.01, max_depth=6, n_estimators=500 ...............
# [CV]  learning_rate=0.01, max_depth=6, n_estimators=500, score=-0.581, total= 2.5min
# [CV] learning_rate=0.01, max_depth=6, n_estimators=500 ...............
# [CV]  learning_rate=0.01, max_depth=6, n_estimators=500, score=-0.578, total= 2.5min
# [CV] learning_rate=0.01, max_depth=6, n_estimators=500 ...............
# [CV]  learning_rate=0.01, max_depth=6, n_estimators=500, score=-0.579, total= 2.5min
# [CV] learning_rate=0.01, max_depth=6, n_estimators=500 ...............
# [CV]  learning_rate=0.01, max_depth=6, n_estimators=500, score=-0.579, total= 2.5min
# [CV] learning_rate=0.01, max_depth=6, n_estimators=1000 ..............
# [CV]  learning_rate=0.01, max_depth=6, n_estimators=1000, score=-0.573, total= 5.1min
# [CV] learning_rate=0.01, max_depth=6, n_estimators=1000 ..............
# [CV]  learning_rate=0.01, max_depth=6, n_estimators=1000, score=-0.579, total= 5.1min
# [CV] learning_rate=0.01, max_depth=6, n_estimators=1000 ..............
# [CV]  learning_rate=0.01, max_depth=6, n_estimators=1000, score=-0.575, total= 5.2min
# [CV] learning_rate=0.01, max_depth=6, n_estimators=1000 ..............
# [CV]  learning_rate=0.01, max_depth=6, n_estimators=1000, score=-0.576, total= 5.1min
# [CV] learning_rate=0.01, max_depth=6, n_estimators=1000 ..............
# [CV]  learning_rate=0.01, max_depth=6, n_estimators=1000, score=-0.576, total= 5.2min
# [CV] learning_rate=0.01, max_depth=6, n_estimators=1250 ..............
# [CV]  learning_rate=0.01, max_depth=6, n_estimators=1250, score=-0.572, total= 6.4min
# [CV] learning_rate=0.01, max_depth=6, n_estimators=1250 ..............
# [CV]  learning_rate=0.01, max_depth=6, n_estimators=1250, score=-0.578, total= 6.4min
# [CV] learning_rate=0.01, max_depth=6, n_estimators=1250 ..............
# [CV]  learning_rate=0.01, max_depth=6, n_estimators=1250, score=-0.574, total= 6.5min
# [CV] learning_rate=0.01, max_depth=6, n_estimators=1250 ..............
# [CV]  learning_rate=0.01, max_depth=6, n_estimators=1250, score=-0.575, total= 6.4min
# [CV] learning_rate=0.01, max_depth=6, n_estimators=1250 ..............
# [CV]  learning_rate=0.01, max_depth=6, n_estimators=1250, score=-0.575, total= 6.4min
# [CV] learning_rate=0.01, max_depth=6, n_estimators=1500 ..............
# [CV]  learning_rate=0.01, max_depth=6, n_estimators=1500, score=-0.571, total= 7.8min
# [CV] learning_rate=0.01, max_depth=6, n_estimators=1500 ..............
# [CV]  learning_rate=0.01, max_depth=6, n_estimators=1500, score=-0.577, total= 7.8min
# [CV] learning_rate=0.01, max_depth=6, n_estimators=1500 ..............
# [CV]  learning_rate=0.01, max_depth=6, n_estimators=1500, score=-0.574, total= 7.9min
# [CV] learning_rate=0.01, max_depth=6, n_estimators=1500 ..............
# [CV]  learning_rate=0.01, max_depth=6, n_estimators=1500, score=-0.575, total= 7.7min
# [CV] learning_rate=0.01, max_depth=6, n_estimators=1500 ..............
# [CV]  learning_rate=0.01, max_depth=6, n_estimators=1500, score=-0.575, total= 7.8min
# [CV] learning_rate=0.01, max_depth=10, n_estimators=500 ..............
# [CV]  learning_rate=0.01, max_depth=10, n_estimators=500, score=-0.574, total= 4.2min
# [CV] learning_rate=0.01, max_depth=10, n_estimators=500 ..............
# [CV]  learning_rate=0.01, max_depth=10, n_estimators=500, score=-0.579, total= 4.2min
# [CV] learning_rate=0.01, max_depth=10, n_estimators=500 ..............
# [CV]  learning_rate=0.01, max_depth=10, n_estimators=500, score=-0.576, total= 4.2min
# [CV] learning_rate=0.01, max_depth=10, n_estimators=500 ..............
# [CV]  learning_rate=0.01, max_depth=10, n_estimators=500, score=-0.577, total= 4.3min
# [CV] learning_rate=0.01, max_depth=10, n_estimators=500 ..............
# [CV]  learning_rate=0.01, max_depth=10, n_estimators=500, score=-0.577, total= 4.3min
# [CV] learning_rate=0.01, max_depth=10, n_estimators=1000 .............
# [CV]  learning_rate=0.01, max_depth=10, n_estimators=1000, score=-0.572, total= 9.5min
# [CV] learning_rate=0.01, max_depth=10, n_estimators=1000 .............
# [CV]  learning_rate=0.01, max_depth=10, n_estimators=1000, score=-0.578, total= 9.1min
# [CV] learning_rate=0.01, max_depth=10, n_estimators=1000 .............
# [CV]  learning_rate=0.01, max_depth=10, n_estimators=1000, score=-0.575, total= 9.0min
# [CV] learning_rate=0.01, max_depth=10, n_estimators=1000 .............
# [CV]  learning_rate=0.01, max_depth=10, n_estimators=1000, score=-0.576, total= 8.9min
# [CV] learning_rate=0.01, max_depth=10, n_estimators=1000 .............
# [CV]  learning_rate=0.01, max_depth=10, n_estimators=1000, score=-0.576, total= 9.0min
# [CV] learning_rate=0.01, max_depth=10, n_estimators=1250 .............
# [CV]  learning_rate=0.01, max_depth=10, n_estimators=1250, score=-0.572, total=11.6min
# [CV] learning_rate=0.01, max_depth=10, n_estimators=1250 .............
# [CV]  learning_rate=0.01, max_depth=10, n_estimators=1250, score=-0.578, total=11.3min
# [CV] learning_rate=0.01, max_depth=10, n_estimators=1250 .............
# [CV]  learning_rate=0.01, max_depth=10, n_estimators=1250, score=-0.574, total=11.5min
# [CV] learning_rate=0.01, max_depth=10, n_estimators=1250 .............
# [CV]  learning_rate=0.01, max_depth=10, n_estimators=1250, score=-0.575, total=11.3min
# [CV] learning_rate=0.01, max_depth=10, n_estimators=1250 .............
# [CV]  learning_rate=0.01, max_depth=10, n_estimators=1250, score=-0.576, total=11.3min
# [CV] learning_rate=0.01, max_depth=10, n_estimators=1500 .............
# [CV]  learning_rate=0.01, max_depth=10, n_estimators=1500, score=-0.572, total=13.8min
# [CV] learning_rate=0.01, max_depth=10, n_estimators=1500 .............
# [CV]  learning_rate=0.01, max_depth=10, n_estimators=1500, score=-0.578, total=13.7min
# [CV] learning_rate=0.01, max_depth=10, n_estimators=1500 .............
# [CV]  learning_rate=0.01, max_depth=10, n_estimators=1500, score=-0.574, total=13.8min
# [CV] learning_rate=0.01, max_depth=10, n_estimators=1500 .............
# [CV]  learning_rate=0.01, max_depth=10, n_estimators=1500, score=-0.575, total=13.6min
# [CV] learning_rate=0.01, max_depth=10, n_estimators=1500 .............
# [CV]  learning_rate=0.01, max_depth=10, n_estimators=1500, score=-0.576, total=14.5min
# [CV] learning_rate=0.05, max_depth=3, n_estimators=500 ...............
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=500, score=-0.574, total= 1.4min
# [CV] learning_rate=0.05, max_depth=3, n_estimators=500 ...............
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=500, score=-0.579, total= 1.3min
# [CV] learning_rate=0.05, max_depth=3, n_estimators=500 ...............
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=500, score=-0.575, total= 1.3min
# [CV] learning_rate=0.05, max_depth=3, n_estimators=500 ...............
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=500, score=-0.576, total= 1.3min
# [CV] learning_rate=0.05, max_depth=3, n_estimators=500 ...............
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=500, score=-0.577, total= 1.3min
# [CV] learning_rate=0.05, max_depth=3, n_estimators=1000 ..............
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=1000, score=-0.571, total= 2.6min
# [CV] learning_rate=0.05, max_depth=3, n_estimators=1000 ..............
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=1000, score=-0.577, total= 3.0min
# [CV] learning_rate=0.05, max_depth=3, n_estimators=1000 ..............
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=1000, score=-0.573, total= 2.7min
# [CV] learning_rate=0.05, max_depth=3, n_estimators=1000 ..............
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=1000, score=-0.574, total= 2.6min
# [CV] learning_rate=0.05, max_depth=3, n_estimators=1000 ..............
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=1000, score=-0.574, total= 2.6min
# [CV] learning_rate=0.05, max_depth=3, n_estimators=1250 ..............
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=1250, score=-0.570, total= 3.3min
# [CV] learning_rate=0.05, max_depth=3, n_estimators=1250 ..............
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=1250, score=-0.576, total= 3.4min
# [CV] learning_rate=0.05, max_depth=3, n_estimators=1250 ..............
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=1250, score=-0.572, total= 3.4min
# [CV] learning_rate=0.05, max_depth=3, n_estimators=1250 ..............
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=1250, score=-0.573, total= 3.3min
# [CV] learning_rate=0.05, max_depth=3, n_estimators=1250 ..............
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=1250, score=-0.574, total= 3.2min
# [CV] learning_rate=0.05, max_depth=3, n_estimators=1500 ..............
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=1500, score=-0.570, total= 3.9min
# [CV] learning_rate=0.05, max_depth=3, n_estimators=1500 ..............
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=1500, score=-0.576, total= 3.9min
# [CV] learning_rate=0.05, max_depth=3, n_estimators=1500 ..............
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=1500, score=-0.572, total= 3.9min
# [CV] learning_rate=0.05, max_depth=3, n_estimators=1500 ..............
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=1500, score=-0.572, total= 3.9min
# [CV] learning_rate=0.05, max_depth=3, n_estimators=1500 ..............
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=1500, score=-0.573, total= 4.0min
# [CV] learning_rate=0.05, max_depth=6, n_estimators=500 ...............
# [CV]  learning_rate=0.05, max_depth=6, n_estimators=500, score=-0.570, total= 2.7min
# [CV] learning_rate=0.05, max_depth=6, n_estimators=500 ...............
# [CV]  learning_rate=0.05, max_depth=6, n_estimators=500, score=-0.576, total= 2.7min
# [CV] learning_rate=0.05, max_depth=6, n_estimators=500 ...............
# [CV]  learning_rate=0.05, max_depth=6, n_estimators=500, score=-0.573, total= 2.7min
# [CV] learning_rate=0.05, max_depth=6, n_estimators=500 ...............
# [CV]  learning_rate=0.05, max_depth=6, n_estimators=500, score=-0.574, total= 2.7min
# [CV] learning_rate=0.05, max_depth=6, n_estimators=500 ...............
# [CV]  learning_rate=0.05, max_depth=6, n_estimators=500, score=-0.574, total= 2.6min
# [CV] learning_rate=0.05, max_depth=6, n_estimators=1000 ..............
# [CV]  learning_rate=0.05, max_depth=6, n_estimators=1000, score=-0.570, total= 5.3min
# [CV] learning_rate=0.05, max_depth=6, n_estimators=1000 ..............
# [CV]  learning_rate=0.05, max_depth=6, n_estimators=1000, score=-0.576, total= 5.2min
# [CV] learning_rate=0.05, max_depth=6, n_estimators=1000 ..............
# [CV]  learning_rate=0.05, max_depth=6, n_estimators=1000, score=-0.573, total= 5.2min
# [CV] learning_rate=0.05, max_depth=6, n_estimators=1000 ..............
# [CV]  learning_rate=0.05, max_depth=6, n_estimators=1000, score=-0.574, total= 5.6min
# [CV] learning_rate=0.05, max_depth=6, n_estimators=1000 ..............
# [CV]  learning_rate=0.05, max_depth=6, n_estimators=1000, score=-0.574, total= 5.5min
# [CV] learning_rate=0.05, max_depth=6, n_estimators=1250 ..............
# [CV]  learning_rate=0.05, max_depth=6, n_estimators=1250, score=-0.570, total= 6.8min
# [CV] learning_rate=0.05, max_depth=6, n_estimators=1250 ..............
# [CV]  learning_rate=0.05, max_depth=6, n_estimators=1250, score=-0.576, total= 7.1min
# [CV] learning_rate=0.05, max_depth=6, n_estimators=1250 ..............
# [CV]  learning_rate=0.05, max_depth=6, n_estimators=1250, score=-0.573, total= 6.9min
# [CV] learning_rate=0.05, max_depth=6, n_estimators=1250 ..............
# [CV]  learning_rate=0.05, max_depth=6, n_estimators=1250, score=-0.574, total= 6.7min
# [CV] learning_rate=0.05, max_depth=6, n_estimators=1250 ..............
# [CV]  learning_rate=0.05, max_depth=6, n_estimators=1250, score=-0.574, total= 6.6min
# [CV] learning_rate=0.05, max_depth=6, n_estimators=1500 ..............
# [CV]  learning_rate=0.05, max_depth=6, n_estimators=1500, score=-0.570, total= 7.8min
# [CV] learning_rate=0.05, max_depth=6, n_estimators=1500 ..............
# [CV]  learning_rate=0.05, max_depth=6, n_estimators=1500, score=-0.577, total= 8.1min
# [CV] learning_rate=0.05, max_depth=6, n_estimators=1500 ..............
# [CV]  learning_rate=0.05, max_depth=6, n_estimators=1500, score=-0.573, total= 7.7min
# [CV] learning_rate=0.05, max_depth=6, n_estimators=1500 ..............
# [CV]  learning_rate=0.05, max_depth=6, n_estimators=1500, score=-0.574, total= 7.8min
# [CV] learning_rate=0.05, max_depth=6, n_estimators=1500 ..............
# [CV]  learning_rate=0.05, max_depth=6, n_estimators=1500, score=-0.574, total= 8.1min
# [CV] learning_rate=0.05, max_depth=10, n_estimators=500 ..............
# [CV]  learning_rate=0.05, max_depth=10, n_estimators=500, score=-0.573, total= 4.7min
# [CV] learning_rate=0.05, max_depth=10, n_estimators=500 ..............
# [CV]  learning_rate=0.05, max_depth=10, n_estimators=500, score=-0.579, total= 4.7min
# [CV] learning_rate=0.05, max_depth=10, n_estimators=500 ..............
# [CV]  learning_rate=0.05, max_depth=10, n_estimators=500, score=-0.575, total= 4.7min
# [CV] learning_rate=0.05, max_depth=10, n_estimators=500 ..............
# [CV]  learning_rate=0.05, max_depth=10, n_estimators=500, score=-0.576, total= 4.6min
# [CV] learning_rate=0.05, max_depth=10, n_estimators=500 ..............
# [CV]  learning_rate=0.05, max_depth=10, n_estimators=500, score=-0.577, total= 4.5min
# [CV] learning_rate=0.05, max_depth=10, n_estimators=1000 .............
# [CV]  learning_rate=0.05, max_depth=10, n_estimators=1000, score=-0.576, total= 9.4min
# [CV] learning_rate=0.05, max_depth=10, n_estimators=1000 .............
# [CV]  learning_rate=0.05, max_depth=10, n_estimators=1000, score=-0.581, total= 9.3min
# [CV] learning_rate=0.05, max_depth=10, n_estimators=1000 .............
# [CV]  learning_rate=0.05, max_depth=10, n_estimators=1000, score=-0.577, total= 9.5min
# [CV] learning_rate=0.05, max_depth=10, n_estimators=1000 .............
# [CV]  learning_rate=0.05, max_depth=10, n_estimators=1000, score=-0.578, total= 9.7min
# [CV] learning_rate=0.05, max_depth=10, n_estimators=1000 .............
# [CV]  learning_rate=0.05, max_depth=10, n_estimators=1000, score=-0.578, total= 9.5min
# [CV] learning_rate=0.05, max_depth=10, n_estimators=1250 .............
# [CV]  learning_rate=0.05, max_depth=10, n_estimators=1250, score=-0.576, total=11.6min
# [CV] learning_rate=0.05, max_depth=10, n_estimators=1250 .............
# [CV]  learning_rate=0.05, max_depth=10, n_estimators=1250, score=-0.582, total=11.5min
# [CV] learning_rate=0.05, max_depth=10, n_estimators=1250 .............
# [CV]  learning_rate=0.05, max_depth=10, n_estimators=1250, score=-0.578, total=11.3min
# [CV] learning_rate=0.05, max_depth=10, n_estimators=1250 .............
# [CV]  learning_rate=0.05, max_depth=10, n_estimators=1250, score=-0.579, total=11.6min
# [CV] learning_rate=0.05, max_depth=10, n_estimators=1250 .............
# [CV]  learning_rate=0.05, max_depth=10, n_estimators=1250, score=-0.579, total=11.6min
# [CV] learning_rate=0.05, max_depth=10, n_estimators=1500 .............
# [CV]  learning_rate=0.05, max_depth=10, n_estimators=1500, score=-0.577, total=13.6min
# [CV] learning_rate=0.05, max_depth=10, n_estimators=1500 .............
# [CV]  learning_rate=0.05, max_depth=10, n_estimators=1500, score=-0.582, total=13.6min
# [CV] learning_rate=0.05, max_depth=10, n_estimators=1500 .............
# [CV]  learning_rate=0.05, max_depth=10, n_estimators=1500, score=-0.578, total=13.6min
# [CV] learning_rate=0.05, max_depth=10, n_estimators=1500 .............
# [CV]  learning_rate=0.05, max_depth=10, n_estimators=1500, score=-0.580, total=14.0min
# [CV] learning_rate=0.05, max_depth=10, n_estimators=1500 .............
# [CV]  learning_rate=0.05, max_depth=10, n_estimators=1500, score=-0.580, total=13.8min
# [Parallel(n_jobs=1)]: Done 120 out of 120 | elapsed: 727.2min finished
# Best parameters: {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 1500}
# Lowest MAE:  0.5726513246233991

# %%
grid_search_results
# Out:
# GridSearchCV(cv=None, error_score=nan,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, gamma=None,
#                                     gpu_id=None, importance_type='gain',
#                                     interaction_constraints=None,
#                                     learning_rate=0.01, max_delta_step=None,
#                                     max_depth=3, min_child_weight=None,
#                                     missing=nan, monotone_constraints=None,
#                                     n_estima...
#                                     random_state=1, reg_alpha=None,
#                                     reg_lambda=None, scale_pos_weight=None,
#                                     subsample=None, tree_method=None,
#                                     validate_parameters=None, verbosity=None),
#              iid='deprecated', n_jobs=None,
#              param_grid={'learning_rate': [0.01, 0.05], 'max_depth': [3, 6, 10],
#                          'n_estimators': [500, 1000, 1250, 1500]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring='neg_mean_absolute_error', verbose=3)

# %%
print(f"Best Model {grid_search_results.best_estimator_}")
best_model =  grid_search_results.best_estimator_
# Out:
# Best Model XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.05, max_delta_step=0, max_depth=3,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=1500, n_jobs=0, num_parallel_tree=1,
#              objective='reg:squarederror', random_state=1, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %%
best_pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('model', best_model)
])

# %%
best_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(memory=None,
#          steps=[('preprocessor',
#                  ColumnTransformer(n_jobs=None, remainder='drop',
#                                    sparse_threshold=0.3,
#                                    transformer_weights=None,
#                                    transformers=[('num',
#                                                   StandardScaler(copy=True,
#                                                                  with_mean=True,
#                                                                  with_std=True),
#                                                   ['cont0', 'cont1', 'cont2',
#                                                    'cont3', 'cont4', 'cont5',
#                                                    'cont6', 'cont7', 'cont8',
#                                                    'cont9', 'cont10', 'cont11',
#                                                    'cont12', 'cont13']),
#                                                  ('cat',
#                                                   OrdinalEnco...
#                               interaction_constraints='', learning_rate=0.05,
#                               max_delta_step=0, max_depth=3, min_child_weight=1,
#                               missing=nan, monotone_constraints='()',
#                               n_estimators=1500, n_jobs=0, num_parallel_tree=1,
#                               objective='reg:squarederror', random_state=1,
#                               reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                               subsample=1, tree_method='exact',
#                               validate_parameters=1, verbosity=None))],
#          verbose=False)

# %%
prediction_valid = best_pipeline.predict(X_valid)
print(mean_absolute_error(y_valid, prediction_valid))
# Out:
# 0.5703273420755884

# %%
predictions = best_pipeline.predict(X_test)

# %%
OUTPUT_PATH = 'output'
def output_submission(prediction, file_name):
    """creating a kaggle submission file

    Args:
        prediction (array): an array of predictions of the test dataset
        file_name (string): a string for the name without the extension
    """
    my_submission = pd.DataFrame({'target': predictions},
                                 index=X_test.index)
    #my_submission.set_index('id')
    file_path = os.path.join(OUTPUT_PATH,file_name)
    my_submission.to_csv(f'{file_path}.csv')
    print(f'A submission file has been made at {file_path}')

# %%
output_submission(predictions, "Submission10")
# Out:
# A submission file has been made at output/Submission10

# %%
df
# Out:
#        cat0 cat1 cat2 cat3 cat4 cat5 cat6 cat7 cat8 cat9  ...     cont5  \
# id                                                        ...
# 1         B    B    B    C    B    B    A    E    C    N  ...  0.400361
# 2         B    B    A    A    B    D    A    F    A    O  ...  0.533087
# 3         A    A    A    C    B    D    A    D    A    F  ...  0.650609
# 4         B    B    A    C    B    D    A    E    C    K  ...  0.668980
# 6         A    A    A    C    B    D    A    E    A    N  ...  0.686964
# ...     ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...       ...
# 499993    B    B    A    A    B    D    A    E    A    I  ...  0.769792
# 499996    A    B    A    C    B    B    A    E    E    F  ...  0.528056
# 499997    B    B    A    C    B    C    A    E    G    F  ...  0.688747
# 499998    A    B    A    C    B    B    A    E    E    I  ...  0.344404
# 499999    A    A    A    C    A    D    A    E    A    O  ...  0.565347
#
#            cont6     cont7     cont8     cont9    cont10    cont11    cont12  \
# id
# 1       0.160266  0.310921  0.389470  0.267559  0.237281  0.377873  0.322401
# 2       0.558922  0.516294  0.594928  0.341439  0.906013  0.921701  0.261975
# 3       0.375348  0.902567  0.555205  0.843531  0.748809  0.620126  0.541474
# 4       0.239061  0.732948  0.679618  0.574844  0.346010  0.714610  0.540150
# 6       0.420667  0.648182  0.684501  0.956692  1.000773  0.776742  0.625849
# ...          ...       ...       ...       ...       ...       ...       ...
# 499993  0.450538  0.934360  1.005077  0.853726  0.422541  1.063463  0.697685
# 499996  0.508502  0.358247  0.257825  0.433525  0.301015  0.268447  0.577055
# 499997  0.372425  0.364936  0.383224  0.551825  0.661007  0.629606  0.714139
# 499998  0.424243  0.382028  0.468819  0.351036  0.288768  0.611169  0.380254
# 499999  0.328669  0.789165  0.960406  0.776019  0.734707  0.484392  0.639754
#
#           cont13    target
# id
# 1       0.869850  8.113634
# 2       0.465083  8.481233
# 3       0.763846  8.364351
# 4       0.280682  8.049253
# 6       0.250823  7.972260
# ...          ...       ...
# 499993  0.506404  7.945605
# 499996  0.823611  7.326118
# 499997  0.245732  8.706755
# 499998  0.332030  7.229569
# 499999  0.689317  8.631146
#
# [300000 rows x 25 columns]
